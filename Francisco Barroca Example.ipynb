# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Francisco Barroca**,
#
# Data Scientist

# %% [markdown]
# *I am interested in Data Science because I've always been great with numbers and problem solving challenges, and I am really critical thinker. I think it can be a great way to work and still do something I love and get paid (well) for it*

# %% [markdown]
# ### The code below creates a list called 'example_list' and prints it

# %%
example_list = [1,2,3,4]
print(example_list)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
#  - one
#  - two
#  - three
#
# ***
#
# [My Portfolio](https://franciscofernandes67.wixsite.com/portfolio)
#
# ***
#
# > abc
